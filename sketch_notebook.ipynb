# %% [markdown]
# ## Hackathon Aveiro 2023

# %%
import pandas as pd

# %%
FOLDER_NAME = './data/'

# %% [markdown]
# ### TODO:
# * read all files
# * see if files has only first value in the rows
# * put latitude longitude in all file
# * add opacity
# * add color for each gas (monoxido de carbono, dioxido de carbono, dioxido nitrogenio)
# * find coordinates
#
#
# questions:
# * what is pm_10 ?
# particulas menores que 10 não sei o quê (qual o tamanho da particula?)
# * what is pm_2_5 ?
# particulas menores que 2 a 5 não sei o quê  (poeira)
# * what is ppm?
# * what is (ug/m3) ?

# %% [markdown]
# ### Dados biblioteca municipal

# %%
df = pd.read_csv('./data/hackathon_air_biblioteca_municipal_aveiro_2023.csv', delimiter=';')
df.head(30)
# Out:
#     carbon_dioxide (ppm)  carbon_monoxide (ug/m3)  nitrogen_dioxide (ug/m3)  \
# 0                  405.0                    252.0                      26.0
# 1                  404.0                    253.0                      27.0
# 2                  404.0                    254.0                      26.0
# 3                  405.0                    257.0                      26.0
# 4                  403.0                    251.0                      26.0
# 5                  405.0                    262.0                      26.0
# 6                  405.0                    262.0                      26.0
# 7                  405.0                    252.0                      26.0
# 8                  404.0                    253.0                      27.0
# 9                  404.0                    254.0                      26.0
# 10                 405.0                    257.0                      26.0
# ...

# %% [markdown]
# ### Dados Centro de Congressos

# %%
df = pd.read_csv('./data/hackathon_air_centro_congressos_aveiro_2023.csv', delimiter=';')
df
# Out:
#        carbon_dioxide (ppm)  carbon_monoxide (ug/m3)  \
# 0                     395.0                    175.0
# 1                     396.0                    178.0
# 2                     404.0                    169.0
# 3                     413.0                    181.0
# 4                     395.0                    186.0
# ...                     ...                      ...
# 12250                 412.0                     92.0
# 12251                 412.0                     91.0
# 12252                 410.0                     90.0
# 12253                 409.0                     92.0
# 12254                   NaN                      NaN
#
#        nitrogen_dioxide (ug/m3)  ozone (ug/m3)  pm_10 (ug/m3)  pm_2_5 (ug/m3)  \
# 0                          24.0          104.0            2.0             1.0
# 1                          26.0          101.0            2.0             1.0
# 2                          25.0          103.0            2.0             1.0
# ...

# %% [markdown]
# ### Dados antiga reitoria UA

# %%
df = pd.read_csv('./data/hackathon_air_antiga_reitoria_ua_aveiro_2023.csv', delimiter=';')
df
# Out:
#        carbon_dioxide (ppm)  carbon_monoxide (ug/m3)  \
# 0                     415.0                    182.0
# 1                     416.0                    182.0
# 2                     415.0                    184.0
# 3                     414.0                    185.0
# 4                     416.0                    189.0
# ...                     ...                      ...
# 17180                 416.0                    251.0
# 17181                 416.0                    252.0
# 17182                 415.0                    255.0
# 17183                 416.0                    253.0
# 17184                   NaN                      NaN
#
#        nitrogen_dioxide (ug/m3)  ozone (ug/m3)  pm_10 (ug/m3)  pm_2_5 (ug/m3)  \
# 0                          35.0           73.0           18.0            11.0
# 1                          36.0           72.0           11.0             7.0
# 2                          36.0           73.0           18.0            11.0
# ...

# %%
aa
